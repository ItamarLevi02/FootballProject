# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors

from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
data = pd.read_csv("./FiveThirtyEight.csv")

# %%
data
# Out:
#        event_date  season  neutral playoff        tm_nano      tm_market  \
# 0      1970-09-18    1970        0     NaN  u98I1lDKQBwZ0    Los Angeles
# 1      1970-09-19    1970        0     NaN  n8CuHV9wbYCqF       New York
# 2      1970-09-20    1970        0     NaN  VkxV91RtzHn65    New England
# 3      1970-09-20    1970        0     NaN  CI5mhfNa0Zqd2    New Orleans
# 4      1970-09-20    1970        0     NaN  D5QY6bOxfn8ZL      Green Bay
# ...           ...     ...      ...     ...            ...            ...
# 12825  2023-01-22    2022        0       d  3VqeLK0LS9rpw        Buffalo
# 12826  2023-01-22    2022        0       d  IwSI92ZDKoazn  San Francisco
# 12827  2023-01-29    2022        0       c  hjjmgzxilGWdr   Philadelphia
# 12828  2023-01-29    2022        0       c  oiGiwWPf0UqMC    Kansas City
# 12829  2023-02-12    2022        1       s  hjjmgzxilGWdr   Philadelphia
#
#         tm_name tm_alias tm_alt_alias       opp_nano  ... opp_qb_elo_win_prob  \
# 0          Rams       LA          LAR  GJizlkzQFaqGA  ...            0.207136
# 1        Giants      NYG          NYG  1vVmWGzUZ1rea  ...            0.290679
# 2      Patriots       NE           NE  mfbu6O5aMHbJg  ...            0.403584
# 3        Saints       NO           NO  mLspw4gJNTQGN  ...            0.525389
# 4       Packers       GB           GB  FCuH1wdksA2DQ  ...            0.439626
# ...         ...      ...          ...            ...  ...                 ...
# 12825     Bills      BUF          BUF  22ZdibiqvfA2D  ...            0.358809
# 12826     49ers       SF           SF  KdjU81i7YSFE7  ...            0.410504
# 12827    Eagles      PHI          PHI  IwSI92ZDKoazn  ...            0.413981
# 12828    Chiefs       KC           KC  22ZdibiqvfA2D  ...            0.419713
# 12829    Eagles      PHI          PHI  oiGiwWPf0UqMC  ...            0.568703
#
#       tm_qb_game_value opp_qb_game_value tm_qb_post_game_value  \
# 0           243.822534         28.506966            139.802476
# 1           140.963726        132.279803            155.962918
# 2            64.876255         22.528537             63.829417
# 3            62.309739         72.278810             78.653177
# 4           -38.355589         85.558735             86.264490
# ...                ...               ...                   ...
# 12825       192.732702        303.726984            225.069808
# 12826       146.767563        105.114287            109.133365
# 12827       157.574864         56.917741            246.826740
# 12828       271.832358         28.185998            280.177715
# 12829              NaN               NaN                   NaN
#
#        opp_qb_post_game_value  tm_qb_elo_post_game  opp_qb_elo_post_game  \
# 0                   47.761507          1587.584454           1407.142436
# 1                   69.807468          1435.220673           1425.212627
# 2                   88.522125          1440.218072           1381.521660
# 3                   86.903458          1393.552066           1511.921807
# 4                   81.893635          1516.039150           1614.578965
# ...                       ...                  ...                   ...
# 12825              230.466056          1675.570770           1690.152492
# 12826              191.883277          1719.153115           1619.647034
# 12827              103.911803          1645.507079           1693.213858
# 12828              210.238050          1708.664922           1678.805820
# 12829                     NaN                  NaN                   NaN
#
#        quality  importance  total_rating
# 0         43.0         NaN           NaN
# 1         17.0         NaN           NaN
# 2         12.0         NaN           NaN
# 3         25.0         NaN           NaN
# 4         79.0         NaN           NaN
# ...        ...         ...           ...
# 12825     99.0       100.0         100.0
# 12826     98.0       100.0          99.0
# 12827     99.0       100.0         100.0
# 12828    100.0       100.0         100.0
# 12829    100.0       100.0         100.0
#
# [12830 rows x 41 columns]
